# %%
import pandas as pd 
import numpy as np

# %%
# !gdown 1upJyp4hzZVONmwiZvOfoKpA28uj2mJwo
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1upJyp4hzZVONmwiZvOfoKpA28uj2mJwo
# To: /Users/ritnil/Scaler-cohorts/final_vg.csv
# 100%|██████████████████████████████████████| 2.04M/2.04M [00:01<00:00, 1.13MB/s]

# %%
data = pd.read_csv('/Users/ritnil/Scaler-cohorts/final_vg.csv')
data
# Out:
#         Rank                                           Name Platform    Year  \
# 0       2061                                           1942      NES  1985.0
# 1       9137                   ¡Shin Chan Flipa en colores!       DS  2007.0
# 2      14279              .hack: Sekai no Mukou ni + Versus      PS3  2012.0
# 3       8359                     .hack//G.U. Vol.1//Rebirth      PS2  2006.0
# 4       7109                   .hack//G.U. Vol.2//Reminisce      PS2  2006.0
# ...      ...                                            ...      ...     ...
# 16647   7925                             Zumba Fitness Rush     X360  2012.0
# 16648   6279                     Zumba Fitness: World Party      Wii  2013.0
# 16649   6977                     Zumba Fitness: World Party     XOne  2013.0
# 16650  15422                                         Zwei!!      PSP  2008.0
# 16651  12919  Zyuden Sentai Kyoryuger: Game de Gaburincho!!      3DS  2013.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = [0,1,2]
y = [5,6,9]

plt.plot(x,y)

# %%
#Univariate : Categorical

# %%
data["Genre"]
# Out:
# 0             Shooter
# 1            Platform
# 2              Action
# 3        Role-Playing
# 4        Role-Playing
#              ...
# 16647          Sports
# 16648            Misc
# 16649            Misc
# 16650    Role-Playing
# 16651          Action
# Name: Genre, Length: 16652, dtype: object

# %%
cat_counts=data["Genre"].value_counts()
cat_counts
# Out:
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
x=cat_counts.index
y=cat_counts
plt.bar(x,y)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.figure(figsize=(12,8)) #6.4 inch by 4.8 inch
x=cat_counts.index
y=cat_counts
plt.bar(x,y)
# Out:
# <BarContainer object of 12 artists>

# %%
x=cat_counts.index
y=cat_counts
plt.barh(x,y)
plt.xticks(rotation=60)

plt.show()

# %%
x=cat_counts.index
y=cat_counts
plt.bar(x,y,width=0.2)  
plt.xticks(rotation=90,fontsize=12)
plt.show()

# %%
x=cat_counts.index
y=cat_counts
plt.bar(x,y,width=0.2, color="orange")  
plt.xticks(rotation=90,fontsize=12)
plt.show()

# %%
x=cat_counts.index
y=cat_counts
plt.bar(x,y,width=0.2, color="orange") 
plt.xticks(rotation=90,fontsize=12)
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("Games Per Genre")

plt.show()

# %%
plt.figure(figsize=(12,8))
x=cat_counts.index
y=cat_counts
plt.bar(x,y,width=0.2,color="Blue")
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("Games Per Genre")
plt.xticks(rotation=90,fontsize=12)
#plt.show() #print


plt.figure(figsize=(12,8))
x=cat_counts.index
y=cat_counts
plt.barh(x,y,width=0.2,color="Orange")
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("Games Per Genre")
plt.xticks(rotation=90,fontsize=12)
plt.show() #print
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 15
#      13 x=cat_counts.index
#      14 y=cat_counts
# ---> 15 plt.barh(x,y,width=0.2,color="Orange")
#      16 plt.xlabel("Genre")
#      17 plt.ylabel("Count")
#
# TypeError: barh() got multiple values for argument 'width'

# %%
#Analogy

# %%
x = 6
y = 8
x
y
# Out:
# 8

# %%
#seaborn

#for horizontal make y = "Genre"
sns.countplot(data=data,
              y="Genre",
              order=data["Genre"].value_counts().index,
             color="blue")
plt.xticks(rotation=90)
plt.show()

# %%
data["Genre"].value_counts().index
# Out:
# Index(['Action', 'Sports', 'Misc', 'Role-Playing', 'Shooter', 'Adventure',
#        'Racing', 'Platform', 'Simulation', 'Fighting', 'Strategy', 'Puzzle'],
#       dtype='object')

# %%
index_1=np.array(['Action', 'Sports', 'Misc', 'Role-Playing', 'Shooter', 'Adventure',
       'Racing', 'Platform', 'Simulation', 'Fighting', 'Strategy', 'Puzzle'])

# %%
index_1.sort()

# %%
index_1
# Out:
# array(['Action', 'Adventure', 'Fighting', 'Misc', 'Platform', 'Puzzle',
#        'Racing', 'Role-Playing', 'Shooter', 'Simulation', 'Sports',
#        'Strategy'], dtype='<U12')

# %%
#Method1
sns.countplot(data=data,
              x="Genre",
              order=index_1,
             color="blue")
plt.xticks(rotation=90)
plt.show()

# %%
#Method2
sns.countplot(
              x=data["Genre"],
             color="blue")
plt.xticks(rotation=90)
plt.show()

# %%
#Histogram

# %%
plt.hist(data["Year"])
plt.show()

# %%
plt.hist(data["Year"],bins=1)
plt.show()

# %%
plt.hist(data["Year"], bins=40)
plt.show()

# %%
count,bins,patches = plt.hist(data["Year"],bins=4)

# %%
count
# Out:
# array([ 215., 1782., 9222., 5162.])

# %%
bins
# Out:
# array([1980., 1990., 2000., 2010., 2020.])

# %%
patches
# Out:
# <BarContainer object of 4 artists>

# %%
#seaborn

# %%
sns.histplot(data["Year"],bins=4)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
sns.histplot(data=data,
             x="Year",
             bins=40)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
#KDE

# %%
sns.kdeplot(data=data,
             x="Year")
# Out:
# <Axes: xlabel='Year', ylabel='Density'>

# %%
sns.kdeplot(x=data["Year"])
# Out:
# <Axes: xlabel='Year', ylabel='Density'>

# %%
#plt.figure(figsize=(12,8))
x = cat_counts.index
y = cat_counts
plt.bar(x,y,width=0.2,color='red')
plt.xticks(rotation=90,fontsize=12)
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Genre vs Frequency')
plt.show() 

#plt.figure(figsize=(12,8))
q = cat_counts.index
r = cat_counts
plt.bar(q,r,width=0.2,color='blue')
plt.xticks(rotation=90,fontsize=12)
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Genre vs Frequency')
plt.show()
