# %%
import matplotlib.pyplot as plt
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
from scipy.stats import poisson

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np, pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

from scipy.stats import spearmanr

# %%
x = np.random.randint(low = 0, high = 100, size = 20)
print(x)

print()

y = x + np.random.normal(3,10,len(x))
print(y)

plt.scatter(x, y)
plt.show()
# Out:
# [87 28 36 66 10 84  0 16 30  3 78 59 53 69 49 74 46 27 33 72]
#
# [99.39028258 14.80867668 37.9903282  74.45807453  8.28585893 82.70738825
#  -2.49203106 20.54481537 26.01251317 12.5290502  66.56282701 82.44833979
#  40.36729712 81.8604277  48.64942212 70.04565851 70.73471236 24.05299497
#  32.53781147 83.89145191]

# %%
plt.scatter(x, y)
plt.vlines(x.mean(), y.min(), y.max(), color = "r")

plt.hlines(y.mean(), x.min(), x.max(), color = "r")

plt.show()

# %%
np.corrcoef(x,y)[0,1]
# Out:
# 0.9402957488642045

# %% [markdown]
# ## perfect linear

# %%
x = np.linspace(1,11, 40)

y = 5*x + 10

plt.vlines(x.mean(), 0, y.max(), color = "r")
plt.hlines(y.mean(), 0, x.max(), color = "r")
plt.scatter(x,y)
plt.show()

# %%
np.corrcoef(x,y)[0,1] # pearson correlation
# Out:
# 1.0

# %% [markdown]
# ## Salary vs Years of Exp.

# %%
data = [(1.0, 4), (4.0, 5), (6.0, 7), (9.0, 9), (11.0, 12), (12.0, 15),
        (13.0, 17), (14.0, 18), (15.0, 28), (15.5, 32)]

# %%
df = pd.DataFrame(data)
df.columns = ["x", "y"]

# %%
df
# Out:
#       x   y
# 0   1.0   4
# 1   4.0   5
# 2   6.0   7
# 3   9.0   9
# 4  11.0  12
# 5  12.0  15
# 6  13.0  17
# 7  14.0  18
# 8  15.0  28
# 9  15.5  32

# %%
df.x.mean()
# Out:
# 10.05

# %%
df.y.mean()
# Out:
# 14.7

# %%
plt.vlines(df.x.mean(), 0, df.y.max(), color = "r")
plt.hlines(df.y.mean(), 0, df.x.max(), color = "r")
plt.scatter(df.x, df.y)
plt.show()

# %%
np.corrcoef(df.x, df.y)[0,1]
# Out:
# 0.8850072528845457

# %%
## pearson : strength of linear relationship 
## spearman : strenth of motonic relationship

# %% [markdown]
# ## Spearman

# %%
df.columns = ["years", "salary"]
df
# Out:
#    years  salary
# 0    1.0       4
# 1    4.0       5
# 2    6.0       7
# 3    9.0       9
# 4   11.0      12
# 5   12.0      15
# 6   13.0      17
# 7   14.0      18
# 8   15.0      28
# 9   15.5      32

# %%
df["rank_years"] = pd.Series.rank(df.years)

df["rank_salary"] = pd.Series.rank(df.salary)

df
# Out:
#    years  salary  rank_years  rank_salary
# 0    1.0       4         1.0          1.0
# 1    4.0       5         2.0          2.0
# 2    6.0       7         3.0          3.0
# 3    9.0       9         4.0          4.0
# 4   11.0      12         5.0          5.0
# 5   12.0      15         6.0          6.0
# 6   13.0      17         7.0          7.0
# 7   14.0      18         8.0          8.0
# 8   15.0      28         9.0          9.0
# 9   15.5      32        10.0         10.0

# %%
plt.scatter(df.rank_years, df.rank_salary)

# %%
np.corrcoef(df.rank_years, df.rank_salary)[0,1]
# Out:
# 0.9999999999999999

# %%
plt.scatter(df.years, df.salary)
plt.show()

# %%
spearmanr(df.years, df.salary)[0]
# Out:
# 0.9999999999999999

# %%
import seaborn as sns
import pandas as pd
anscombe = sns.load_dataset('anscombe')
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
np.corrcoef(anscombe[anscombe["dataset"]=="I"]["x"], anscombe[anscombe["dataset"]=="I"]["y"])[0,1]
# Out:
# 0.81642051634484

# %%
np.corrcoef(anscombe[anscombe["dataset"]=="I"]["x"], anscombe[anscombe["dataset"]=="I"]["y"])[0,1]

# %%
np.corrcoef(anscombe[anscombe["dataset"]=="II"]["x"], anscombe[anscombe["dataset"]=="II"]["y"])[0,1]
# Out:
# 0.8162365060002427

# %%
np.corrcoef(anscombe[anscombe["dataset"]=="III"]["x"], anscombe[anscombe["dataset"]=="III"]["y"])[0,1]
# Out:
# 0.8162867394895982

# %%
np.corrcoef(anscombe[anscombe["dataset"]=="IV"]["x"], anscombe[anscombe["dataset"]=="IV"]["y"])[0,1]
# Out:
# 0.816521436888503

# %%
poisson.cdf(mu=(3/20),k=1)
# Out:
# 0.9898141728888165

# %%
poisson.pmf(mu=((30*240)/3600),k=1)
# Out:
# 0.2706705664732254

# %%
poisson.cdf(mu=(0.25*74),k=15)
# Out:
# 0.24902769151284776

# %%
1-poisson.cdf(mu=(0.25*74),k=7)
# Out:
# 0.9979029280379949

# %%
poisson.pmf(mu=10,k=0)
# Out:
# 4.5399929762484854e-05
