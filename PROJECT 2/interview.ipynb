# %%
l = [1,2,3,4]
l1 = ['a','b','c','d']
list(zip(l1,l))
# Out:
# [('a', 1), ('b', 2), ('c', 3), ('d', 4)]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
l = [1,2,3,4]
sns.barplot(l,color='g')
plt.title("ABC")
plt.bar
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       4 sns.barplot(l,color='g')
#       5 plt.title("ABC")
# ----> 6 plt.bar(height=l)
#
# TypeError: bar() missing 1 required positional argument: 'x'
